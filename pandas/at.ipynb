# %%
import pandas as pd

# Leitura dos arquivos CSV
vendas_df = pd.read_csv('Vendas2017.csv', sep=';', encoding='ISO-8859-1')
produtos = pd.read_csv('CadastroProdutos.csv', sep=';', encoding='ISO-8859-1')
cliente = pd.read_csv('ClientesDF.csv', sep=';', encoding='ISO-8859-1')
lojas = pd.read_csv('Lojas.csv', sep=';', encoding='ISO-8859-1')

# Removendo colunas indesejadas do dataframe 'cliente'
cliente = cliente.drop(['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis=1, errors='ignore')

# Selecionando colunas específicas dos dataframes
cliente = cliente[['ÿID Cliente', 'E-mail']]
lojas = lojas[['ÿID Loja', 'Nome da Loja']]
produtos = produtos[['ID Produto', 'ï»¿Nome da Marca']]

# Renomeando colunas para corrigir problemas de codificação
cliente = cliente.rename(columns={'ÿID Cliente': 'ID Cliente'})
lojas = lojas.rename(columns={'ÿID Loja': 'ID Loja'})
produtos = produtos.rename(columns={'ï»¿Nome da Marca': 'Nome da Marca'})

# Juntando as tabelas com merge
vendas_df = vendas_df.merge(produtos, on='ID Produto')
vendas_df = vendas_df.merge(lojas, on='ID Loja')
vendas_df = vendas_df.merge(cliente, on='ID Cliente')
# Exibindo o dataframe final para verificação
frequencia_clientes = vendas_df['E-mail'].value_counts()
display(frequencia_clientes)

frequencia_clientes[:5].plot(figsize=(15,5), yticks=(range(0,100,10)))
# Out:
# E-mail
# karen33@adventure-works.com      77
# chloe77@adventure-works.com      74
# julia43@adventure-works.com      69
# gilbert9@adventure-works.com     68
# destiny66@adventure-works.com    68
#                                  ..
# mblemen9o@ebay.com                1
# rebecca15@adventure-works.com     1
# kevin10@adventure-works.com       1
# siliffe8l@spotify.com             1
# clifford8@adventure-works.com     1
# Name: count, Length: 38907, dtype: int64
# <Axes: xlabel='E-mail'>

# %%
# Agrupando dataframes usando o groupby

display(vendas_df)
vendas_lojas = vendas_df.groupby('Nome da Loja').sum()
vendas_lojas = vendas_lojas[['Quantidade Vendida']].sort_values('Quantidade Vendida', ascending=False)
display(vendas_lojas)

vendas_lojas[:5].plot(figsize=(15,10),kind='bar')
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
maior_valor = vendas_lojas['Quantidade Vendida'].max()
loja_maior = vendas_lojas['Quantidade Vendida'].idxmax()

print(loja_maior, maior_valor)

menor_valor = vendas_lojas['Quantidade Vendida'].min()
loja_menor = vendas_lojas['Quantidade Vendida'].idxmax()

outrometodo_menor = vendas_lojas[-1:]

print(loja_menor, menor_valor)
print(outrometodo_menor)
# Out:
# Loja Contoso Catalog  1029117
# Loja Contoso Catalog  234
#                        Quantidade Vendida
# Nome da Loja
# Loja Contoso Venezia                  234

# %%
qtd_vendida = vendas_df['Quantidade Vendida'].sum()
qtd_devolvida = vendas_df['Quantidade Devolvida'].sum()

print('{:.2%}'.format(qtd_devolvida/qtd_vendida))


lojaContoso = vendas_df[vendas_df['ID Loja']== 306]

vendas_lojasContoso = lojaContoso['Quantidade Vendida'].sum()
devolucoes_lojasContoso = lojaContoso['Quantidade Devolvida'].sum()

print('{:.2%}'.format(devolucoes_lojasContoso/vendas_lojasContoso))
# Out:
# 1.17%
# 1.33%
